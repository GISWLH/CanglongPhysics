# %%
import h5py
f = h5py.File('/gz-data/ERA5_2023_weekly.h5', 'r')

# %%
import matplotlib.pyplot as plt

plt.imshow(f['surface'][0, 0, :, :])

# %%
from convert_dict_to_pytorch_arrays import load_normalization_arrays

# 调用函数获取四个数组
surface_mean, surface_std, upper_mean, upper_std = load_normalization_arrays('ERA5_1940_2019_combined_mean_std.json')

# %%
surface_mean.shape
# Out:
# (1, 17, 1, 721, 1440)
